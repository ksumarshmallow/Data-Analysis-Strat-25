# %% [markdown]
# # **Практика 7 (семинар). Корреляция**

# %% [markdown]
# [SmartLMS](https://edu.hse.ru/mod/quiz/view.php?id=1772505)

# %% [markdown]
# Этот набор данных содержит записи, относящиеся к кампании прямого маркетинга банка. Цель этой кампании, чтобы клиенты оформили срочный вклад в банке:
#
#
# | Признак             | Описание                                |
# | ------------------- | --------------------------------------- |
# | `age` |  возраст клиента |
# | `job` |  профессия клиента |
# | `marital` |  семейной положение (**0** - женат; **1** - в разводе; **2** - одинок) |
# | `education` |  уровень образования |
# | `loan` |  наличие кредитов (**0** - нет; **1** - есть) |
# | `contact` |  тип контакта с клиентом (**1** - телефон, **0** - электронная почта) |
# | `campaign` |  количество контактов, выполненных в ходе данной кампании и для данного клиента |
# | `previous` |  количество дней, прошедших с момента последнего контакта с клиентом в рамках предыдущей кампании |
# | `poutcome` |  результат предыдущей маркетинговой кампании (**0** - не участвовал, **1** - провал, **2** - успех) |
# | `emp.var.rate` |  изменения уровня безработицы относительно прошлого квартала (**отрицательное значение** - уровень безработицы снизился; положительное значение - уровень безработицы увеличился; **0** - не изменился) |
# | `cons.price.idx` |  индекс потребительских цен |
# | `euribor3m` |  усредненная межбанкоковская процента ставка |
# | `nr.employed` |  количество сотрудников банка |
# | `y`  | открыл ли клиент срочный вклад (**0** - нет, **1** - да) |

# %%
import pandas as pd
df = pd.read_csv('data/bankdata.csv')

# %% [markdown]
# ## **Задание 1**

# %% [markdown]
# ### *Задание 1.1*

# %% [markdown]
# >*Укажите количество наблюдений в данных.*

# %% [markdown]
# ### *Задание 1.2*

# %% [markdown]
# >*Укажите количество признаков, в которых есть пропуски.*

# %% [markdown]
# ### *Задание 1.3*

# %% [markdown]
# >*Укажите шкалу измерения каждого признака.*
# >
# >| Признак             | Шкала |
# >| ------------------- | -------- |
# >| `age`               |          |
# >| `job`               |          |
# >| `marital`           |          |
# >| `education`         |          |
# >| `loan`              |          |
# >| `contact`           |          |
# >| `campaign`          |          |
# >| `previous`          |          |
# >| `poutcome`          |          |
# >| `emp.var.rate`      |          |
# >| `cons.price.idx`    |          |
# >| `euribor3m`         |          |
# >| `nr.employed`       |          |
# >| `y`                 |          |

# %% [markdown]
# Варианты на выбор:
# - количественный дискретный
# - количественный непрерывный
# - категориальный номинальный
# - категориальный порядковый
# - категориальный бинарный

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 2**

# %% [markdown]
# >*Вам представлены диаграммы рассеяния признаков из данных:*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# >*Укажите про какой график идет речь:*
# >- По горизонтальной и вертикальной оси один и тот же признак: `???`
# >- Между признаками обратная взаимосвязь: `???`
# >- Между признаками прямая взаимосязь, но при это не автокорреляция: `???`
# >- Если один признак будет уменьшаться, то второй, скорее всего, тоже: `???`
# >- Если один признак будет увеличиваться, то второй, скорее всего, уменьшится: `???`
# >- Корреляция между признаками равна 1: `???`
# >- Корреляция между признаками будет положительная: `???`
# >- Корреляция между признаками будет отрицательная: `???`

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 3**

# %% [markdown]
# >*Рассчитайте и проинтепретируйте*
# >
# >*Коэффициент корреляции, между количеством сотрудников (`nr.employed`) и тем, открыл ли клиент вклад (`y`):* `???`.
# >
# > *Выберите верное утверждение*:
# >   - между признаками прямая линейная связь
# >   - между признаками обратная линейная связь
# >   - между признаками возрастающая монотонная связь
# >   - между признаками убывающая монотонная связь
# >   - причиной решения клиента открыть вклад является количество сотрудников

# %% [markdown]
# >*Cтепень линейной взаимосвязи между возрастом клиента (`age`) и индексом потребительских цен (`cons.price.idx`):* `???`
# >
# > *Выберите верное утверждение*:
# >   - при увеличении возраста клиента индекс потребительских цен тоже возрастает
# >   - при снижении возраста клиента индекс потребительских цен тоже снизится
# >   - между признаками практически отсутствует линейная взаимосвязь
# >   - между признаками убывающая монотонная связь
# >   - возраст клиент авлияет на индекс потребительских цен

# %% [markdown]
# >*Cтепень монотонной взаимосвязи между усредненной межбанкоковской процентной ставкой (`euribor3m`) и индексом потребительских цен (`cons.price.idx`):* `???`
# >
# > *Выберите верное утверждение*:
# >   - при увеличении процентной ставки индекс потребительских цен тоже возрастает
# >   - при увеличении процентной ставки индекс потребительских цен снизится
# >   - между признаками существует линейная связь
# >   - между признаками убывающая монотонная связь
# >   - процентная ставка влияет на индекс потребительских цен

# %% [markdown]
# >*Коэффициент корреляции, который чувствителен к выбросам, между количеством сотрудников (`nr.employed`) и количество дней, прошедших с момента последнего контакта с клиентом в рамках предыдущей кампании (`previous`): `???`*
# >
# > *Выберите верное утверждение*:
# >   - между признаками прямая линейная связь
# >   - между признаками обратная линейная связь
# >   - между признаками возрастающая мононотонная связь
# >   - между признаками убывающая монотонная связь
# >   - при увеличении количества сотрудников количество контактов с клиентами тоже возрастет

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 4**

# %% [markdown]
# >*Создайте функцию `ed_coded`, которая будет перекодировать значения признака `education` по следующему правилу:*
# >
# >| Значение	| Закодированное значение |
# >| ---- | --- |
# >| 'illiterate' | 1 |
# >| 'basic.4y' | 2 |
# >| 'basic.6y' | 2 |
# >| 'basic.9y' | 2 |
# >| 'high.school' | 3 |
# >| 'professional.course' | 4 |
# >| 'university.degree' | 5 |

# %%
def ed_coded(x):
    ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 5**

# %% [markdown]
# >*Создайте новый признак `education_coded` с помощью функции из прошлого задания. Постройте корреляционную матрицу и заполните пропуски в утверждениях про корреляцию признаков с `education_coded`:*
# >
# >- Наиболее сильная возрастающая `???` связь `education_coded` с признаком `???`. Значение корреляции между ними составляет `???`.
# >- Наиболее сильная убывающая `???` связь `education_coded` с признаком `???`. Значение корреляции между ними составляет `???`.
# >- Самая слабая `???` связь `education_coded` с признаком `???`.

# %% [markdown]
# ---

# %% [markdown]
# ## **Задание 6**

# %% [markdown]
# >*Постройте корреляционную матрицу, которая будет показывать степень линейной взаимосвязи между признаками. Заполните пропуски в утверждениях ниже про корреляцию с количеством дней, прошедших с момента последнего контакта с клиентом в рамках предыдущей кампании (`previous`)*
# >
# >**HINT**: Учтите, что степень линейной взаимосвязи можно интепретировать не между всеми признаками.
# >
# >- Признак `previous` имеют самую сильную линейную взаимосвязь с признаком `???`. Значение коэффициента корреляции между ними составляет `???`. Полученное значение говорит о том, что при сокращении `previous`, второй признак `???`.
# >- Самую слабую линейную взаимосвязь с признаком `previous` имеет признак `???`. Значение коэффициента корреляции между ними равно `???`. Такое значение говорит, что между признаками отсутсвует линейная взаимосвязь, но это не значит, что они не могут быть связаны какой-либо другой зависимостью.

# %% [markdown]
# ---
