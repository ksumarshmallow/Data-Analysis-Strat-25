# %% [markdown]
# # **НЭ. Задание `A2`**

# %% [markdown]
# [SmartLMS](https://edu.hse.ru/mod/quiz/view.php?id=1618959)

# %% [markdown]
# **Необходимо соотнести признак и ттип визуализации**. Необходимо понимание типов признаков и вариантов графиков - посмотреть можно в [Хэндбуке, главе #4](https://edu.hse.ru/course/view.php?id=236211&section=4)

# %% [markdown]
# ## **Вопрос 1**

# %% [markdown]
# >*Соотнесите тип визуализации и признак*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# | признак | тип визуализации |
# | --- | --- |
# | Количество посетителей спортивного зала бравших/не бравших тренировку с личным тренером |  |
# | Распределение посетителей спортивного зала по возрастным группам (<25 / 25-29 / 30-34 / 35-40) | |
# | Распределение стоимости месячного абонемента в спортивный зал | |
# | Динамика посещения спортивного зала по месяцам | |

# %% [markdown]
# Тип визуализации на выбор:
# - столбчатая диаграмма
# - круговая диаграмма
# - ящик с усами
# - линейный график

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 2**

# %% [markdown]
# >*Соотнесите тип визуализации и признак*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# | признак | тип визуализации |
# | --- | --- |
# | Распределение городов по местоположению (материковые / прибрежные / горные) |  |
# | Средняя температура воздуха для разных погодных условий (облачно /дождь / снег / ясно)	 | |
# | Распределение температуры воздух | |
# | Зависимость влажности воздуха от скорости ветра | |

# %% [markdown]
# Тип визуализации на выбор:
# - столбчатая диаграмма
# - круговая диаграмма
# - гистограмма
# - диаграмма рассеяния

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 3**

# %% [markdown]
# >*Соотнесите тип визуализации и признак*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# | признак | тип визуализации |
# | --- | --- |
# | Распределение результатов по математике (0-100) |  |
# | Распределение сдающих экзамен (мужчины/женщины)	 | |
# | Зависимость среднего балла по чтению от образования родителей (ср. общее/ср. проф./бакалавр/магистр/кан. наук/доктор наук) | |
# | Зависимость результатов экзамена по чтению (0-100) от результатов по письму (0-100) | |

# %% [markdown]
# Тип визуализации на выбор:
# - столбчатая диаграмма
# - круговая диаграмма
# - гистограмма
# - диаграмма рассеяния

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 4**

# %% [markdown]
# >*Соотнесите тип визуализации и признак*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# | признак | тип визуализации |
# | --- | --- |
# | Распределение размеров штрафов за административные нарушения (руб.) |  |
# | Динамика количества преступлений в течение года | |
# | Динамика количества преступлений в течение недели	 | |
# | Распределение количества краж за 50 лет | |

# %% [markdown]
# Тип визуализации на выбор:
# - ящик с усами
# - линейный график
# - гистограмма
# - столбчатая диаграмма

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 5**

# %% [markdown]
# >*Соотнесите тип визуализации и признак*

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# | признак | тип визуализации |
# | --- | --- |
# | Распределение количества отелей по звёздности (1-5) |  |
# | Распределение стоимости одной ночи в отеле ($) | |
# | Среднее значение рейтинга (0-10) по категориям: сервис, удобства, расположение, чистота   | |
# | Зависимость общего рейтинга отеля (0-10) от стоимости одной ночи в нем ($) | |

# %% [markdown]
# Тип визуализации на выбор:
# - ящик с усами
# - круговая диаграмма
# - диаграмма рассеяния
# - столбчатая диаграмма
