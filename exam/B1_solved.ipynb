# %% [markdown]
# # **НЭ. Задание `B1`**

# %% [markdown]
# **В части `B` нам предоставляют датасет, по которому нам и необходимо ответить на вопросы. На все задания части `B` - один датасет**
#
# Для выполнения задания **`B1`** проверяется умение строить визуализации. В задании чаще предоставляется несколько графиков и спрашивается "какой график соответствует визуализации такого-то признака" или "какой график не соответствует визуализации признака такого-то типа". Необходимо построить соответствующие графики на предоставленном датасете и ответить на вопрос.
#
# Для выполнения этого задания также может потребоваться знание о составлении частотных таблиц `value_counts()`.
#
# Для прорешивания заданий данного типа можно прочитать в [Хэндбука, главе #4](https://edu.hse.ru/course/view.php?id=236211&section=4)

# %% [markdown]
# [SmartLMS](https://edu.hse.ru/course/section.php?id=1060342#module-1220253)

# %%
import pandas as pd

# %% [markdown]
# ## **Вопрос 1**

# %% [markdown]
# Вам предоставлен датасет, который содержит информацию о погоде в течение года.
#
# Датасет содержит следующие признаки:
#
# | признак | описание |
# | --- | --- |
# | season	| сезон (1 – весна, 2 – лето, 3 – осень, 4 – зима) |
# | atemp	 | средняя температура (в градусах Цельсия) |
#  | humidity	  | относительная влажность воздуха |
#  | windspeed	 |  скорость ветра |

# %% [markdown]
# >*Укажите, какой из графиков **не** является визуализацией количественных признаков из данных.*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('data/train1_b.csv')
df.head()
# Out:
#    season   atemp  humidity  windspeed
# 0       1  14.395        81        0.0
# 1       1  13.635        80        0.0
# 2       1  13.635        80        0.0
# 3       1  14.395        75        0.0
# 4       1  14.395        75        0.0

# %%
df["atemp"].plot(kind="hist", figsize=(6, 4));

# %%
df["humidity"].plot(kind="hist", figsize=(6, 4));

# %%
df["windspeed"].plot(kind="hist", figsize=(6, 4));

# %% [markdown]
# **Ответ**: `D`

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 2**

# %% [markdown]
# Вам предоставлен датасет, который содержит информацию о блюдах ресторана быстрого питания.
#
# Датасет содержит следующие признаки:
#
# | признак | описание |
# | --- | --- |
#  | cat | в какой категории находится блюдо (1 – Beef & Pork, 2 – Beverages, 3 – Breakfast, и т.д.) |
#   |  total_fat | 	 количество жиров (в процентах от дневной нормы) |
# | protein	 | количество белка |
# | calcium	 | количество углеводов |

# %% [markdown]
# >*Какой из графиков визуализирует количество блюд в каждой категории (`cat`)?*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('data/train2_b.csv')
df.head()
# Out:
#    cat  total_fat  protein  calcium
# 0    3         20       17       25
# 1    3         12       18       25
# 2    3         35       14       25
# 3    3         43       21       30
# 4    3         35       21       25

# %%
df["cat"].value_counts().plot(kind="bar", figsize=(6, 4));

# %% [markdown]
# **Ответ**: `A`

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 3**

# %% [markdown]
# Вам предоставлен датасет, оторый содержит информацию о социально-экономических характеристиках разных стран.
#
# Датасет содержит следующие признаки:
#
# | признак | описание |
# | --- | --- |
# | Country | название страны |
# | Region | географический регион (Australia and New Zealand — A, Central and Eastern Europe — B, Eastern Asia — C, и т.д.) |
# | Economy	 | показатель экономического развития страны |
# | Health	 | показатель здоровья населения страны |

# %% [markdown]
# >*Какой из графиков не иллюстрирует количество стран (`Country`) в каждом регионе (`Region`)?*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Ответ**: `C`
# - регионов слишком много получается)

# %%
df = pd.read_csv('data/train3_b.csv')
df.head()
# Out:
#        Country Region  Economy  Health
# 0  Switzerland      J     1.40    0.94
# 1      Iceland      J     1.30    0.95
# 2      Denmark      J     1.33    0.87
# 3       Norway      J     1.46    0.89
# 4       Canada      F     1.33    0.91

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 4**

# %% [markdown]
# Вам предоставлен датасет, который содержит информацию о заемщиках банка в Германии.
#
# Датасет содержит следующие признаки:
#
# | признак | описание |
# | --- | --- |
# | Age	| возраст заемщика |
# | Sex	 | пол заемщика (женщины — 1, мужчины — 2) |
#  | Credit amount		  | размер кредита, в немецких марках |
#  | Duration	 |   срок кредитования, в месяцах |

# %% [markdown]
# >*Какой из графиков визуализирует соотношение мужчин и женщин в данных (`Sex`)?*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('data/train4_b.csv')
df.head()
# Out:
#    Age  Sex  Credit amount  Duration
# 0   67    0           1169         6
# 1   22    1           5951        48
# 2   49    0           2096        12
# 3   45    0           7882        42
# 4   53    0           4870        24

# %%
df["Sex"].value_counts().plot(kind="pie", figsize=(5, 5));

# %% [markdown]
# **Ответ**: `C`

# %% [markdown]
# ---

# %% [markdown]
# ## **Вопрос 5**

# %% [markdown]
# Вам предоставлен датасет, который содержит информацию о погоде в течение года.
#
# Датасет содержит следующие признаки:
#
# | признак | описание |
# | --- | --- |
# | Soil_Type  | тип почвы (1 — глина, 2 — суглинок, 3 — песок) |
#  | Sunlight_Hours  | среднее количество часов, которое растение проводило на солнце |
#  | Temperature  | температура воздуха, в которой росли растения (градусы Цельсия) |
#  | Humidity  | относительная влажность воздуха, в которой росли растения (%) |

# %% [markdown]
# >*Какой из графиков визуализирует влажность воздуха (`Humidity`)?*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('data/train5_b.csv')
df.head()
# Out:
#    Soil_Type  Sunlight_Hours  Temperature   Humidity
# 0          2        5.192294    31.719602  61.591861
# 1          3        4.033133    28.919484  52.422276
# 2          2        8.892769    23.179059  44.660539
# 3          2        8.241144    18.465886  46.433227
# 4          3        8.374043    18.128741  63.625923

# %%
df["Humidity"].plot(kind="box", vert=False, figsize=(5, 4));

# %% [markdown]
# **Ответ**: `B`
